# %% [markdown]
# <a href="https://colab.research.google.com/github/himeshdowlaghar/Statistical-Machine-Learning/blob/main/STML_Assignment_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Salary_Data[1].csv')
data
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df=pd.DataFrame(data)
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
x=df.drop('Salary',axis=1);
y=df['Salary'];

# %%
plt.scatter(x,y,color="blue",label="Actual");
plt.xlabel("Features(Experience)");
plt.ylabel("Target(Salary)");
plt.title("Experience VS Salary")
# Out:
# Text(0.5, 1.0, 'Experience VS Salary')

# %%
model =LinearRegression()

# %%
model.fit(x,y)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)
y_pred=model.predict(x_test)

# %%
plt.plot(x_test,y_pred,color="red")
plt.title("Best Fit LIne");
plt.legend()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
print("Mean Squared Error: ",mse)
print("Mean Absolute Error: ",mae)
# Out:
# Mean Squared Error:  44526862.33914307
# Mean Absolute Error:  5584.687682921728

# %% [markdown]
# 2nd question

# %%
data2 = {
    'Feature1': [1.2, 2.4, 3.5, 4.1, 1.9, 3.7, 2.1, 3.3, 2.8, 4],
    'Feature2': [2.3, 1.9, 2.7, 3, 2.8, 2.5, 3.2, 2.4, 3.1, 3.3],
    'Feature3': [3.1, 2.8, 1.5, 3.6, 2.5, 1.9, 2.2, 3, 1.8, 2.7],
    'Feature4': [4.2, 3.5, 2.9, 4.8, 3.2, 4, 4.1, 4.5, 3.6, 4.9],
    'Target': [15.6, 13.1, 12.4, 18.2, 14.1, 16, 14.5, 17.3, 14.9, 19.2]
}
df2=pd.DataFrame(data2)
df2
# Out:
#    Feature1  Feature2  Feature3  Feature4  Target
# 0       1.2       2.3       3.1       4.2    15.6
# 1       2.4       1.9       2.8       3.5    13.1
# 2       3.5       2.7       1.5       2.9    12.4
# 3       4.1       3.0       3.6       4.8    18.2
# 4       1.9       2.8       2.5       3.2    14.1
# 5       3.7       2.5       1.9       4.0    16.0
# 6       2.1       3.2       2.2       4.1    14.5
# 7       3.3       2.4       3.0       4.5    17.3
# 8       2.8       3.1       1.8       3.6    14.9
# 9       4.0       3.3       2.7       4.9    19.2

# %%
x2=df2.drop('Target',axis=1)
y2=df2['Target']

# %%
sns.pairplot(x2)

# %%
model.fit(x2,y2)
x2_train,x2_test,y2_train,y2_test=train_test_split(x2,y2,test_size=0.2,random_state=1)
y2_pred=model.predict(x2_test)

# %%
plt.plot(y2_test,y2_pred,color="orange")

# %%
mse2=mean_squared_error(y2_test,y2_pred)
mae2=mean_absolute_error(y2_test,y2_pred)
print("Mean Squared Error: ",mse2)
print("Mean Absolute Error: ",mae2)
# Out:
# Mean Squared Error:  0.16861547432231788
# Mean Absolute Error:  0.40854282643847206
